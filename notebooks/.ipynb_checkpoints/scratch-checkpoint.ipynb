# %%
from os.path import expanduser
import pandas as pd
import numpy as np

anew_dictionary_filepath = expanduser(
        '~/Dropbox/PhD/Projects/Appraisal Network Estimation/appraisal_network_dynamics/bagofwords/ANEW_stemmed.csv')
# anew_dictionary_filepath = expanduser(
#     '~/Documents/koa/College/UCSB/2019-2020/Research/appraisal_network_dynamics/bagofwords/ANEW_stemmed.csv')
anew = pd.read_csv(anew_dictionary_filepath)
anew_dicts = {'valence': {}, 'arousal': {}, 'dominance': {}}
for i in range(len(anew)):
    anew_dicts['valence'][anew.ix[i]['Description']] = (
        anew.ix[i]['Valence Mean'])
    anew_dicts['arousal'][anew.ix[i]['Description']] = (
        anew.ix[i]['Arousal Mean'])
    anew_dicts['dominance'][anew.ix[i]['Description']] = (
        anew.ix[i]['Dominance Mean'])
# Out:
# /home/omid/.local/lib/python3.5/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if sys.path[0] == '':

# %%
np.max( np.array(list(anew_dicts['valence'].values())) )
# Out:
# 8.82

# %%
np.max( np.array(list(anew_dicts['arousal'].values())) )
# Out:
# 8.17

# %%
np.max( np.array(list(anew_dicts['dominance'].values())) )
# Out:
# 7.88

# %%
import pickle as pk
import numpy as np

with open('/home/omid/Datasets/Jeopardy/Appraisals_and_scores_data.pk', 'rb') as handle:
    data = pk.load(handle)
    
for team_id, team_data in data.items():
    print('For team {}: '.format(team_id))
    for influence_matrix in team_data['influences']:
        print(np.array(influence_matrix))
    print(team_data['scores'])
    print('\n\n')
# Out:
# For team 7:
# [[ 25  25  25  25]
#  [ 40   0  40  20]
#  [  0 100   0   0]
#  [  1   1   1  97]]
# [[25 25 25 25]
#  [25 25 25 25]
#  [ 5 20  5 70]
#  [ 1  1  1 97]]
# [[25 25 25 25]
#  [25 25 25 25]
#  [10 20 10 60]
#  [ 1  1  1 97]]
# [[25 25 25 25]
#  [25 25 25 25]
#  [20 30 20 30]
#  [ 0  2  2 96]]
# [[70 10 10 10]
#  [25 25 25 25]
#  [25 25 25 25]
#  [ 1  2  2 95]]
# [[25 25 25 25]
#  [25 25 25 25]
#  [25 25 25 25]
#  [ 1  1  1 97]]
# [[70 10 10 10]
#  [25 25 25 25]
#  [35  0 30 35]
#  [ 2  3  3 92]]
# [[25 25 25 25]
#  [25 25 25 25]
#  [35  0 30 35]
#  [10 10 10 70]]
# [[80  0 10 10]
#  [25 25 25 25]
#  [35  0 30 35]
#  [10 10 10 63]]
# {1: 4, 2: 4, 4: 4, 6: -1, 7: -1, 8: -1, 9: -1, 10: -1, 11: 4, 12: -1, 14: 4, 16: 4, 17: 4, 18: 4, 19: 4, 20: 4, 21: 4, 22: 4, 23: 4, 24: -1, 25: 4, 26: -1, 27: 4, 28: -2, 29: 4, 30: 4, 31: -1, 32: 4, 33: -1, 34: -1, 36: 4, 37: 4, 38: 4, 39: -1, 40: -1, 41: -1, 42: -2, 43: -1, 44: 4, 45: 4}
#
#
#
# For team 10:
# [[40 20  0 40]
#  [25 25 25 25]
# ...
